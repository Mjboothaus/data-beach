# %%
print("Hello World")
# Out:
# Hello World

# %%
# COMMENT: Python / Jupyter and paths are an interesting story... for your info...
import sys
sys.path
# Out:
# ['/workspace/gitpod-hello-conda',
#  '/home/gitpod/.gitpod-code/extensions/ms-python.python-2020.10.332292344/pythonFiles',
#  '/home/gitpod/.gitpod-code/extensions/ms-python.python-2020.10.332292344/pythonFiles/lib/python',
#  '/workspace/miniforge3/envs/dbooth/lib/python38.zip',
#  '/workspace/miniforge3/envs/dbooth/lib/python3.8',
#  '/workspace/miniforge3/envs/dbooth/lib/python3.8/lib-dynload',
#  '',
#  '/workspace/miniforge3/envs/dbooth/lib/python3.8/site-packages',
#  '/workspace/miniforge3/envs/dbooth/lib/python3.8/site-packages/IPython/extensions',
#  '/home/gitpod/.ipython']

# %%
import pandas as pd
import asyncio

# %%
# https://data.gov.sg/dataset/aeaf4704-5be1-4b33-993d-c70d8dcc943e/download

# %%
import httpx

# %%
def get_list_open_datasets_singapore():
    DATA_URL = "https://data.gov.sg/api/action/package_list"
    response = httpx.get(DATA_URL)
    #async with httpx.AsyncClient() as client:
    #    response = await client.get(DATA_URL)
    return response, response.json()

# %%
response, result = get_list_open_datasets_singapore()

# %%
response
# Out:
# <Response [200 OK]>

# %%
type(result)
# Out:
# dict

# %%
result
# Out:
# p-in-food-beverage-services-annual',
#   'key-indicators-by-industry-group-in-health-services-annual',
#   'key-indicators-by-industry-group-in-transport-storage-services-annual',
#   'key-indicators-of-all-services-industries-by-size-of-operating-receipts-annual',
#   'key-indicators-of-food-beverage-services-by-size-of-operating-receipts-annual',
#   'key-indicators-on-divorces-annual',
#   'key-indicators-on-the-elderly-annual',
#   'key-indicators-on-the-youth-annual',
#   'key-stats-since-1960-demand-for-rental-and-sold-flats',
#   'kindergartens',
#   'labour-force-participation-rate-for-hdb-population-by-ethnic-group-and-flat-type',
#   'land-area-and-dwelling-units-by-town',
#   'lasalle-and-nafa-intake-enrolment-and-graduates',
#   'length-of-road-maintained-by-lta',
#   'libraries',
#   'licensed-food-establishments-by-category-annual',
#   'licensed-food-establishments-by-grade',
#   'licensed-food-establishments-food-factories',
# ...
