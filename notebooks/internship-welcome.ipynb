# %% [markdown]
# # Welcome to your Internship at DataBooth
#
# We'd like to get you into solving problems with data and coding as soon as possible. So Let's go...

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# If you're notfamiliar with it, "Hello World" is sort of the minimum viable program. See "Minimum Viable Product" for the thinking on this. Now that's out of the way - let's move on.

# %%
# rich is a text library for Python and within Jupyter notebooks
import rich

# %%
from pathlib import Path

# %%
from rich.jupyter import print
print("Hello, [green bold]World![/] :ninja:")
# Out:
# Hello, World! :ninja:

# %%
from rich.__main__ import make_test_card
print(make_test_card())
# Out:
#                                         Rich features
#
#     Colors    ✓ 4-bit color                 ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
#               ✓ 8-bit color                 ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
#               ✓ Truecolor (16.7 million)    ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
#               ✓ Dumb terminals              ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
#               ✓ Automatic color conversion  ▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
#
#     Styles    All ansi styles: bold, dim, italic, underline, strikethrough, reverse, and
#               even blink.
#
#      Text     Word wrap text. Justify left, center, right or full.
#
#               Lorem ipsum dolor   Lorem ipsum dolor    Lorem ipsum dolor Lorem  ipsum  dolor
#               sit amet,               sit amet,                sit amet, sit           amet,
#               consectetur            consectetur             consectetur consectetur
#               adipiscing elit.     adipiscing elit.     adipiscing elit. adipiscing    elit.
#               Quisque in metus     Quisque in metus     Quisque in metus Quisque  in   metus
#               sed sapien              sed sapien              sed sapien sed          sapien
#               ultricies pretium a ultricies pretium  ultricies pretium a ultricies pretium a
#               at justo. Maecenas     a at justo.      at justo. Maecenas at justo.  Maecenas
#               luctus velit et      Maecenas luctus       luctus velit et luctus   velit   et
#               auctor maximus.      velit et auctor       auctor maximus. auctor maximus.
#                                        maximus.
#
#     Asian     🇨🇳  该库支持中文，日文和韩文文本！
#    language   🇯🇵  ライブラリは中国語、日本語、韓国語のテキストをサポートしています
#    support    🇰🇷  이 라이브러리는 중국어, 일본어 및 한국어 텍스트를 지원합니다
#
#     Markup    Rich supports a simple bbcode-like markup for color, style, and emoji! 👍 🍎
#               🐜 🐻 🥖 🚌
#
#     Tables     Date           Title                      Production Budget       Box Office
#               ──────────────────────────────────────────────────────────────────────────────
#                Dec 20, 2019   Star Wars: The Rise of          $275,000,000     $375,126,118
#                               Skywalker
#                May 25, 2018   Solo: A Star Wars Story         $275,000,000     $393,151,347
#                Dec 15, 2017   Star Wars Ep. VIII: The         $262,000,000   $1,332,539,889
#                               Last Jedi
#                May 19, 1999   Star Wars Ep. I: The            $115,000,000   $1,027,044,677
#                               phantom Menace
#
#     Syntax       1 def iter_last(values: Iterable[T]  {
#  highlighting    2 │   """Iterate and generate a tup  │   'foo': [
#       &          3 │   iter_values = iter(values)     │   │   3.1427,
#     pretty       4 │   try:                           │   │   (
#    printing      5 │   │   previous_value = next(ite  │   │   │   'Paul Atreides',
#                  6 │   except StopIteration:          │   │   │   'Vladimir Harkonnen',
#                  7 │   │   return                     │   │   │   'Thufir Hawat'
#                  8 │   for value in iter_values:      │   │   )
#                  9 │   │   yield False, previous_val  │   ],
#                 10 │   │   previous_value = value     │   'atomic': (False, True, None)
#                 11 │   yield True, previous_value     }
#
#    Markdown   # Markdown                              ╔════════════════════════════════════╗
#                                                       ║              Markdown              ║
#               Supports much of the *markdown*,        ╚════════════════════════════════════╝
#               __syntax__!
#                                                       Supports much of the markdown, syntax!
#               - Headers
#               - Basic formatting: **bold**,            • Headers
#               *italic*, `code`                         • Basic formatting: bold, italic,
#               - Block quotes                             code
#               - Lists, and more...                     • Block quotes
#                                                        • Lists, and more...
#
#     +more!    Progress bars, columns, styled logging handler, tracebacks, etc...

# %% [markdown]
# ## Reproducibility, versioning etc
#
# We want everything that we do to be reproducible. Michael is a scientist by background (he did his Ph.D. in the area of mathematical theory of solutions) -- so we value reproducibilty.
#
# Versioning matters - it shows change through time. There are various approaches to this problem - nowadays Git is pretty standard tooling and we use GitHub.com as our "versioning backend".

# %% [markdown]
# ## Package management
#
# Mondern software is all about package management.

# %% [markdown]
# ## It's a Broken (Computing) World
#
# When stuff works it's a bonus -- and it does a lot of the time. When it doesn't it can lead to frustration (and tears).

# %% [markdown]
# ## Example of using Rich

# %%
"""
Demonstrates how to display a tree of files / directories with the Tree renderable.
"""

import os
import pathlib
import sys

from rich import print
from rich.filesize import decimal
from rich.markup import escape
from rich.text import Text
from rich.tree import Tree


def walk_directory(directory: pathlib.Path, tree: Tree) -> None:
    """Recursively build a Tree with directory contents."""
    # Sort dirs first then by filename
    paths = sorted(
        pathlib.Path(directory).iterdir(),
        key=lambda path: (path.is_file(), path.name.lower()),
    )
    for path in paths:
        # Remove hidden files
        if path.name.startswith("."):
            continue
        if path.is_dir():
            style = "dim" if path.name.startswith("__") else ""
            branch = tree.add(
                f"[bold magenta]:open_file_folder: [link file://{path}]{escape(path.name)}",
                style=style,
                guide_style=style,
            )
            walk_directory(path, branch)
        else:
            text_filename = Text(path.name, "green")
            text_filename.highlight_regex(r"\..*$", "bold red")
            text_filename.stylize(f"link file://{path}")
            file_size = path.stat().st_size
            text_filename.append(f" ({decimal(file_size)})", "blue")
            icon = "🐍 " if path.suffix == ".py" else "📄 "
            tree.add(Text(icon) + text_filename)

# %%
directory = Path().cwd().parent

tree = Tree(
    f":open_file_folder: [link file://{directory}]{directory}",
    guide_style="bold bright_blue",
)
walk_directory(pathlib.Path(directory), tree)
print(tree)
# Out:
# 📂 ]8;id=253410;file:///workspace/db-hello-gitpod\/workspace/db-hello-gitpod]8;;\
# ┣━━ 📂 ]8;id=198069;file:///workspace/db-hello-gitpod/docs\docs]8;;\
# ┃   ┣━━ 📂 ]8;id=246170;file:///workspace/db-hello-gitpod/docs/_static\_static]8;;\
# ┃   ┣━━ 📄 ]8;id=481954;file:///workspace/db-hello-gitpod/docs/authors.rst\authors]8;;\]8;id=481954;file:///workspace/db-hello-gitpod/docs/authors.rst\.rst]8;;\ (41 bytes)
# ┃   ┣━━ 📄 ]8;id=246378;file:///workspace/db-hello-gitpod/docs/changelog.rst\changelog]8;;\]8;id=246378;file:///workspace/db-hello-gitpod/docs/changelog.rst\.rst]8;;\ (43 bytes)
# ┃   ┣━━ 🐍 ]8;id=502689;file:///workspace/db-hello-gitpod/docs/conf.py\conf]8;;\]8;id=502689;file:///workspace/db-hello-gitpod/docs/conf.py\.py]8;;\ (9.5 kB)
# ┃   ┣━━ 📄 ]8;id=209154;file:///workspace/db-hello-gitpod/docs/index.rst\index]8;;\]8;id=209154;file:///workspace/db-hello-gitpod/docs/index.rst\.rst]8;;\ (2.3 kB)
# ┃   ┣━━ 📄 ]8;id=818035;file:///workspace/db-hello-gitpod/docs/license.rst\license]8;;\]8;id=818035;file:///workspace/db-hello-gitpod/docs/license.rst\.rst]8;;\ (67 bytes)
# ┃   ┣━━ 📄 ]8;id=4685;file:///workspace/db-hello-gitpod/docs/Makefile\Makefile]8;;\ (1.2 kB)
# ┃   ┣━━ 📄 ]8;id=656544;file:///workspace/db-hello-gitpod/docs/readme.rst\readme]8;;\]8;id=656544;file:///workspace/db-hello-gitpod/docs/readme.rst\.rst]8;;\ (39 bytes)
# ┃   ┗━━ 📄 ]8;id=616033;file:///workspace/db-hello-gitpod/docs/requirements.txt\requirements]8;;\]8;id=616033;file:///workspace/db-hello-gitpod/docs/requirements.txt\.txt]8;;\ (233 bytes)
# ┣━━ 📂 ]8;id=701411;file:///workspace/db-hello-gitpod/md\md]8;;\
# ┃   ┣━━ 📄 ]8;id=918712;file:///workspace/db-hello-gitpod/md/ethics_checklist.md\ethics_checklist]8;;\]8;id=918712;file:///workspace/db-hello-gitpod/md/ethics_checklist.md\.md]8;;\ (3.9 kB)
# ┃   ┣━━ 📄 ]8;id=537170;file:///workspace/db-hello-gitpod/md/intro_training.md\intro_training]8;;\]8;id=537170;file:///workspace/db-hello-gitpod/md/intro_training.md\.md]8;;\ (4.7 kB)
# ┃   ┣━━ 📄 ]8;id=484242;file:///workspace/db-hello-gitpod/md/possible_projects_summary.md\possible_projects_summary]8;;\]8;id=484242;file:///workspace/db-hello-gitpod/md/possible_projects_summary.md\.md]8;;\ (2.1 kB)
# ┃   ┣━━ 📄 ]8;id=412766;file:///workspace/db-hello-gitpod/md/project_explore_datasette.md\project_explore_datasette]8;;\]8;id=412766;file:///workspace/db-hello-gitpod/md/project_explore_datasette.md\.md]8;;\ (799 bytes)
# ┃   ┗━━ 📄 ]8;id=64460;file:///workspace/db-hello-gitpod/md/README.md\README]8;;\]8;id=64460;file:///workspace/db-hello-gitpod/md/README.md\.md]8;;\ (317 bytes)
# ┣━━ 📂 ]8;id=22733;file:///workspace/db-hello-gitpod/notebooks\notebooks]8;;\
# ┃   ┣━━ 📄 ]8;id=95983;file:///workspace/db-hello-gitpod/notebooks/hello-world-notebook.ipynb\hello-world-notebook]8;;\]8;id=95983;file:///workspace/db-hello-gitpod/notebooks/hello-world-notebook.ipynb\.ipynb]8;;\ (28.8 kB)
# ┃   ┣━━ 📄 ]8;id=491112;file:///workspace/db-hello-gitpod/notebooks/internship-welcome.ipynb\internship-welcome]8;;\]8;id=491112;file:///workspace/db-hello-gitpod/notebooks/internship-welcome.ipynb\.ipynb]8;;\ (85.6 kB)
# ┃   ┣━━ 📄 ]8;id=72259;file:///workspace/db-hello-gitpod/notebooks/project_explore_datasette.ipynb\project_explore_datasette]8;;\]8;id=72259;file:///workspace/db-hello-gitpod/notebooks/project_explore_datasette.ipynb\.ipynb]8;;\ (4.8 kB)
# ┃   ┗━━ 📄 ]8;id=621132;file:///workspace/db-hello-gitpod/notebooks/README.md\README]8;;\]8;id=621132;file:///workspace/db-hello-gitpod/notebooks/README.md\.md]8;;\ (17 bytes)
# ┣━━ 📂 ]8;id=420659;file:///workspace/db-hello-gitpod/src\src]8;;\
# ┃   ┣━━ 📂 ]8;id=588038;file:///workspace/db-hello-gitpod/src/databooth\databooth]8;;\
# ┃   ┃   ┣━━ 🐍 ]8;id=998937;file:///workspace/db-hello-gitpod/src/databooth/__init__.py\__init__]8;;\]8;id=998937;file:///workspace/db-hello-gitpod/src/databooth/__init__.py\.py]8;;\ (586 bytes)
# ┃   ┃   ┣━━ 🐍 ]8;id=650120;file:///workspace/db-hello-gitpod/src/databooth/skeleton.py\skeleton]8;;\]8;id=650120;file:///workspace/db-hello-gitpod/src/databooth/skeleton.py\.py]8;;\ (4.2 kB)
# ┃   ┃   ┗━━ 🐍 ]8;id=911667;file:///workspace/db-hello-gitpod/src/databooth/utils.py\utils]8;;\]8;id=911667;file:///workspace/db-hello-gitpod/src/databooth/utils.py\.py]8;;\ (988 bytes)
# ┃   ┗━━ 📂 ]8;id=233127;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info\db_hello_gitpod.egg-info]8;;\
# ┃       ┣━━ 📄 ]8;id=436893;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/dependency_links.txt\dependency_links]8;;\]8;id=436893;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/dependency_links.txt\.txt]8;;\ (1 byte)
# ┃       ┣━━ 📄 ]8;id=736075;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/not-zip-safe\not-zip-safe]8;;\ (1 byte)
# ┃       ┣━━ 📄 ]8;id=774450;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/PKG-INFO\PKG-INFO]8;;\ (530 bytes)
# ┃       ┣━━ 📄 ]8;id=643944;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/requires.txt\requires]8;;\]8;id=643944;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/requires.txt\.txt]8;;\ (86 bytes)
# ┃       ┣━━ 📄 ]8;id=330782;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/SOURCES.txt\SOURCES]8;;\]8;id=330782;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/SOURCES.txt\.txt]8;;\ (937 bytes)
# ┃       ┗━━ 📄 ]8;id=529938;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/top_level.txt\top_level]8;;\]8;id=529938;file:///workspace/db-hello-gitpod/src/db_hello_gitpod.egg-info/top_level.txt\.txt]8;;\ (10 bytes)
# ┣━━ 📂 ]8;id=768185;file:///workspace/db-hello-gitpod/tests\tests]8;;\
# ┃   ┣━━ 🐍 ]8;id=54672;file:///workspace/db-hello-gitpod/tests/conftest.py\conftest]8;;\]8;id=54672;file:///workspace/db-hello-gitpod/tests/conftest.py\.py]8;;\ (277 bytes)
# ┃   ┗━━ 🐍 ]8;id=963506;file:///workspace/db-hello-gitpod/tests/test_skeleton.py\test_skeleton]8;;\]8;id=963506;file:///workspace/db-hello-gitpod/tests/test_skeleton.py\.py]8;;\ (587 bytes)
# ┣━━ 📄 ]8;id=495321;file:///workspace/db-hello-gitpod/AUTHORS.rst\AUTHORS]8;;\]8;id=495321;file:///workspace/db-hello-gitpod/AUTHORS.rst\.rst]8;;\ (83 bytes)
# ┣━━ 📄 ]8;id=452098;file:///workspace/db-hello-gitpod/CHANGELOG.rst\CHANGELOG]8;;\]8;id=452098;file:///workspace/db-hello-gitpod/CHANGELOG.rst\.rst]8;;\ (128 bytes)
# ┣━━ 📄 ]8;id=676764;file:///workspace/db-hello-gitpod/environment.yml\environment]8;;\]8;id=676764;file:///workspace/db-hello-gitpod/environment.yml\.yml]8;;\ (535 bytes)
# ┣━━ 📄 ]8;id=766853;file:///workspace/db-hello-gitpod/LICENSE\LICENSE]8;;\ (1.1 kB)
# ┣━━ 📄 ]8;id=335274;file:///workspace/db-hello-gitpod/pyproject.toml\pyproject]8;;\]8;id=335274;file:///workspace/db-hello-gitpod/pyproject.toml\.toml]8;;\ (311 bytes)
# ┣━━ 📄 ]8;id=57575;file:///workspace/db-hello-gitpod/README.md\README]8;;\]8;id=57575;file:///workspace/db-hello-gitpod/README.md\.md]8;;\ (593 bytes)
# ┣━━ 📄 ]8;id=431399;file:///workspace/db-hello-gitpod/setup.cfg\setup]8;;\]8;id=431399;file:///workspace/db-hello-gitpod/setup.cfg\.cfg]8;;\ (3.8 kB)
# ┣━━ 🐍 ]8;id=592114;file:///workspace/db-hello-gitpod/setup.py\setup]8;;\]8;id=592114;file:///workspace/db-hello-gitpod/setup.py\.py]8;;\ (712 bytes)
# ┗━━ 📄 ]8;id=54773;file:///workspace/db-hello-gitpod/tox.ini\tox]8;;\]8;id=54773;file:///workspace/db-hello-gitpod/tox.ini\.ini]8;;\ (2.0 kB)
